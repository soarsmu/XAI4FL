# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.39.0.tar.gz (356 kB)
#      |████████████████████████████████| 356 kB 10.8 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from shap) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from shap) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from shap) (0.22.2.post1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from shap) (1.1.5)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.7/dist-packages (from shap) (4.41.1)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from shap) (0.51.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->shap) (57.2.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba->shap) (0.34.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (1.0.1)
# Building wheels for collected packages: shap
#   Building wheel for shap (setup.py) ... done
#   Created wheel for shap: filename=shap-0.39.0-cp37-cp37m-linux_x86_64.whl size=491631 sha256=1392fdc9342035be477f1c4fb19d0d212aea76733106df909749bda25e6cec25
#   Stored in directory: /root/.cache/pip/wheels/ca/25/8f/6ae5df62c32651cd719e972e738a8aaa4a87414c4d2b14c9c0
# Successfully built shap
# Installing collected packages: slicer, shap
# Successfully installed shap-0.39.0 slicer-0.0.7

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from google.colab import files
import pandas as pd
import json
import re
import ast
import numpy as np
from sklearn.metrics import precision_score, recall_score, accuracy_score
import numpy as np
import shap
from sklearn import metrics

# %%
def process_spectra(file_obj, file_name):
    file_string = str(file_obj[file_name])

    return file_string.split("\\n")

# %%
def process_matrix(file_obj, file_name):
    file_string = str(file_obj[file_name])

    result = file_string.split("\\n")
    result[0] = result[0].replace("b'", "")

    for i in range(len(result)):
        result[i] = result[i].split(" ")
        result[i] = [int(x) if x.isdigit() else x for x in result[i]]
        lastel = result[i][-1]
        if lastel == "+":
            result[i][-1] = "PASS"
        elif lastel == "-":
            result[i][-1] = "FAIL"
    
    return result

# %%
def make_line_in_txt_shap(shap_value_exp_obj_instance, instance_name):
    feature_indexes = []
    new_list = []
    for i in range(len(df.iloc[instance_name])):
        if df.iloc[instance_name][i] == 1:
            feature_indexes.append(i)
    for i in feature_indexes:
        new_list.append(";".join([list(x.columns)[i], str(shap_value_exp_obj_instance[i].values)]))
    return new_list

# %%
def write_output_file(filename, obj, is_reverse=False):
    with open(filename, 'w') as file:
        sorted_dict = sorted(obj.items(), key=lambda x: x[1], reverse=is_reverse)
        for i in sorted_dict:
            file.write(";".join([i[0], str(i[1])]) + "\n")

# %%
spectra_file = files.upload()
matrix_file = files.upload()
# Out:
#      <input type="file" id="files-9842985d-e1c3-4c28-b0c1-4cc6c3def3a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9842985d-e1c3-4c28-b0c1-4cc6c3def3a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving spectra to spectra
#      <input type="file" id="files-32956317-af88-4881-9b65-08c174f260f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32956317-af88-4881-9b65-08c174f260f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving matrix to matrix

# %%
spectra_list = process_spectra(spectra_file, list(spectra_file.keys())[0])
spectra_list[-1] = "Pass/Fail"
spectra_list[0] = spectra_list[0].replace("b'", "")

# %%
matrix_list = process_matrix(matrix_file, list(matrix_file.keys())[0])

# %%
matrix_list.pop()
# Out:
# ["'"]

# %%
df = pd.DataFrame(data=matrix_list, columns=spectra_list)

# %%
df
# Out:
#     org.apache.commons.math3.util.MathArrays$1#674  ...  Pass/Fail
# 0                                                0  ...       PASS
# 1                                                0  ...       PASS
# 2                                                0  ...       PASS
# 3                                                0  ...       PASS
# 4                                                0  ...       PASS
# 5                                                0  ...       PASS
# 6                                                0  ...       PASS
# 7                                                0  ...       PASS
# 8                                                0  ...       PASS
# 9                                                0  ...       PASS
# 10                                               0  ...       PASS
# 11                                               0  ...       PASS
# 12                                               0  ...       PASS
# 13                                               0  ...       PASS
# 14                                               0  ...       PASS
# 15                                               0  ...       PASS
# 16                                               0  ...       PASS
# 17                                               0  ...       PASS
# 18                                               0  ...       FAIL
# 19                                               0  ...       PASS
# 20                                               0  ...       PASS
# 21                                               0  ...       PASS
#
# [22 rows x 974 columns]

# %%
x = df[spectra_list[:len(spectra_list)-1]]
y = df["Pass/Fail"]

# %%
fails = []
passes = []
i = 0
for result in y:
    if result == "FAIL":
        fails.append(i)
    else:
        passes.append(i)
    i += 1

# %%
if len(fails) == 1:
    df = df.append(df.iloc[fails[0]])
    x = df[spectra_list[:len(spectra_list)-1]]
    y = df["Pass/Fail"]

# %%
if (df.shape[0] < 6):
    df = df.append(df)
    x = df[spectra_list[:len(spectra_list)-1]]
    y = df["Pass/Fail"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=1)

# %%
model = KNeighborsClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred=model.predict(x_test)

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         PASS       1.00      1.00      1.00         5
#
#     accuracy                           1.00         5
#    macro avg       1.00      1.00      1.00         5
# weighted avg       1.00      1.00      1.00         5

# %%
shap_to_txt = {}

explainer = shap.KernelExplainer(model.predict_proba, x_train)
shap_values = explainer.shap_values(x)


for i in fails:
    temp_list = []
    for index, j in enumerate(shap_values[0][i]):
        temp_list.append(spectra_list[index] + ";" + str(j))
    shap_to_txt[x.iloc[i].name] = temp_list
# Out:
# HBox(children=(FloatProgress(value=0.0, max=23.0), HTML(value='')))

# %%
shap_to_txt
# Out:
# {18: ['org.apache.commons.math3.util.MathArrays$1#674;0.0',
#   'org.apache.commons.math3.util.MathArrays$1#678;0.0',
#   'org.apache.commons.math3.util.MathArrays$1#680;0.0',
#   'org.apache.commons.math3.util.MathArrays$1#681;0.0',
#   'org.apache.commons.math3.util.MathArrays$1#683;0.0',
#   'org.apache.commons.math3.util.MathArrays$1#684;0.0',
#   'org.apache.commons.math3.util.MathArrays$1#687;0.0',
#   'org.apache.commons.math3.util.MathArrays$1#689;0.0',
#   'org.apache.commons.math3.util.MathArrays#51;0.0',
#   'org.apache.commons.math3.util.MathArrays#88;0.0',
#   'org.apache.commons.math3.util.MathArrays#89;0.0',
#   'org.apache.commons.math3.util.MathArrays#92;0.0',
#   'org.apache.commons.math3.util.MathArrays#93;0.0',
#   'org.apache.commons.math3.util.MathArrays#94;0.0',
#   'org.apache.commons.math3.util.MathArrays#96;0.0',
#   'org.apache.commons.math3.util.MathArrays#110;0.0',
#   'org.apache.commons.math3.util.MathArrays#111;0.0',
#   'org.apache.commons.math3.util.MathArrays#114;0.0',
#   'org.apache.commons.math3.util.MathArrays#115;0.0',
#   'org.apache.commons.math3.util.MathArrays#116;0.0',
#   'org.apache.commons.math3.util.MathArrays#118;0.0',
#   'org.apache.commons.math3.util.MathArrays#132;0.0',
#   'org.apache.commons.math3.util.MathArrays#133;0.0',
#   'org.apache.commons.math3.util.MathArrays#136;0.0',
#   'org.apache.commons.math3.util.MathArrays#137;0.0',
#   'org.apache.commons.math3.util.MathArrays#138;0.0',
#   'org.apache.commons.math3.util.MathArrays#140;0.0',
#   'org.apache.commons.math3.util.MathArrays#154;0.0',
#   'org.apache.commons.math3.util.MathArrays#155;0.0',
#   'org.apache.commons.math3.util.MathArrays#158;0.0',
#   'org.apache.commons.math3.util.MathArrays#159;0.0',
#   'org.apache.commons.math3.util.MathArrays#160;0.0',
#   'org.apache.commons.math3.util.MathArrays#162;0.0',
#   'org.apache.commons.math3.util.MathArrays#173;0.0',
#   'org.apache.commons.math3.util.MathArrays#174;0.0',
#   'org.apache.commons.math3.util.MathArrays#175;0.0',
#   'org.apache.commons.math3.util.MathArrays#177;0.0',
#   'org.apache.commons.math3.util.MathArrays#188;0.0',
#   'org.apache.commons.math3.util.MathArrays#189;0.0',
#   'org.apache.commons.math3.util.MathArrays#190;0.0',
#   'org.apache.commons.math3.util.MathArrays#192;0.0',
#   'org.apache.commons.math3.util.MathArrays#203;0.0',
#   'org.apache.commons.math3.util.MathArrays#204;0.0',
#   'org.apache.commons.math3.util.MathArrays#205;0.0',
#   'org.apache.commons.math3.util.MathArrays#206;0.0',
#   'org.apache.commons.math3.util.MathArrays#208;0.0',
#   'org.apache.commons.math3.util.MathArrays#219;0.0',
#   'org.apache.commons.math3.util.MathArrays#220;0.0',
#   'org.apache.commons.math3.util.MathArrays#221;0.0',
#   'org.apache.commons.math3.util.MathArrays#222;0.0',
#   'org.apache.commons.math3.util.MathArrays#224;0.0',
#   'org.apache.commons.math3.util.MathArrays#235;0.0',
#   'org.apache.commons.math3.util.MathArrays#236;0.0',
#   'org.apache.commons.math3.util.MathArrays#237;0.0',
#   'org.apache.commons.math3.util.MathArrays#239;0.0',
#   'org.apache.commons.math3.util.MathArrays#250;0.0',
#   'org.apache.commons.math3.util.MathArrays#251;0.0',
#   'org.apache.commons.math3.util.MathArrays#252;0.0',
#   'org.apache.commons.math3.util.MathArrays#254;0.0',
#   'org.apache.commons.math3.util.MathArrays#279;0.0',
#   'org.apache.commons.math3.util.MathArrays#280;0.0',
#   'org.apache.commons.math3.util.MathArrays#281;0.0',
#   'org.apache.commons.math3.util.MathArrays#283;0.0',
#   'org.apache.commons.math3.util.MathArrays#285;0.0',
#   'org.apache.commons.math3.util.MathArrays#286;0.0',
#   'org.apache.commons.math3.util.MathArrays#287;0.0',
#   'org.apache.commons.math3.util.MathArrays#288;0.0',
#   'org.apache.commons.math3.util.MathArrays#291;0.0',
#   'org.apache.commons.math3.util.MathArrays#292;0.0',
#   'org.apache.commons.math3.util.MathArrays#297;0.0',
#   'org.apache.commons.math3.util.MathArrays#298;0.0',
#   'org.apache.commons.math3.util.MathArrays#299;0.0',
#   'org.apache.commons.math3.util.MathArrays#300;0.0',
#   'org.apache.commons.math3.util.MathArrays#303;0.0',
#   'org.apache.commons.math3.util.MathArrays#304;0.0',
#   'org.apache.commons.math3.util.MathArrays#310;0.0',
#   'org.apache.commons.math3.util.MathArrays#313;0.0',
#   'org.apache.commons.math3.util.MathArrays#315;0.0',
#   'org.apache.commons.math3.util.MathArrays#329;0.0',
#   'org.apache.commons.math3.util.MathArrays#346;0.0',
#   'org.apache.commons.math3.util.MathArrays#347;0.0',
#   'org.apache.commons.math3.util.MathArrays#351;0.0',
#   'org.apache.commons.math3.util.MathArrays#352;0.0',
#   'org.apache.commons.math3.util.MathArrays#354;0.0',
#   'org.apache.commons.math3.util.MathArrays#355;0.0',
#   'org.apache.commons.math3.util.MathArrays#356;0.0',
#   'org.apache.commons.math3.util.MathArrays#359;0.0',
#   'org.apache.commons.math3.util.MathArrays#360;0.0',
#   'org.apache.commons.math3.util.MathArrays#365;0.0',
#   'org.apache.commons.math3.util.MathArrays#366;0.0',
#   'org.apache.commons.math3.util.MathArrays#367;0.0',
#   'org.apache.commons.math3.util.MathArrays#370;0.0',
#   'org.apache.commons.math3.util.MathArrays#371;0.0',
#   'org.apache.commons.math3.util.MathArrays#377;0.0',
#   'org.apache.commons.math3.util.MathArrays#380;0.0',
#   'org.apache.commons.math3.util.MathArrays#383;0.0',
#   'org.apache.commons.math3.util.MathArrays#385;0.0',
#   'org.apache.commons.math3.util.MathArrays#389;0.0',
#   'org.apache.commons.math3.util.MathArrays#390;0.0',
#   'org.apache.commons.math3.util.MathArrays#392;0.0',
#   'org.apache.commons.math3.util.MathArrays#407;0.0',
#   'org.apache.commons.math3.util.MathArrays#408;0.0',
#   'org.apache.commons.math3.util.MathArrays#418;0.0',
#   'org.apache.commons.math3.util.MathArrays#419;0.0',
#   'org.apache.commons.math3.util.MathArrays#431;0.0',
#   'org.apache.commons.math3.util.MathArrays#432;0.0',
#   'org.apache.commons.math3.util.MathArrays#433;0.0',
#   'org.apache.commons.math3.util.MathArrays#434;0.0',
#   'org.apache.commons.math3.util.MathArrays#439;0.0',
#   'org.apache.commons.math3.util.MathArrays#451;0.0',
#   'org.apache.commons.math3.util.MathArrays#452;0.0',
#   'org.apache.commons.math3.util.MathArrays#453;0.0',
#   'org.apache.commons.math3.util.MathArrays#456;0.0',
#   'org.apache.commons.math3.util.MathArrays#467;0.0',
#   'org.apache.commons.math3.util.MathArrays#468;0.0',
#   'org.apache.commons.math3.util.MathArrays#469;0.0',
#   'org.apache.commons.math3.util.MathArrays#472;0.0',
#   'org.apache.commons.math3.util.MathArrays#483;0.0',
#   'org.apache.commons.math3.util.MathArrays#484;0.0',
#   'org.apache.commons.math3.util.MathArrays#485;0.0',
#   'org.apache.commons.math3.util.MathArrays#486;0.0',
#   'org.apache.commons.math3.util.MathArrays#490;0.0',
#   'org.apache.commons.math3.util.MathArrays#553;0.0',
#   'org.apache.commons.math3.util.MathArrays#554;0.0',
#   'org.apache.commons.math3.util.MathArrays#555;0.0',
#   'org.apache.commons.math3.util.MathArrays#556;0.0',
#   'org.apache.commons.math3.util.MathArrays#557;0.0',
#   'org.apache.commons.math3.util.MathArrays#558;0.0',
#   'org.apache.commons.math3.util.MathArrays#559;0.0',
#   'org.apache.commons.math3.util.MathArrays#560;0.0',
#   'org.apache.commons.math3.util.MathArrays#561;0.0',
#   'org.apache.commons.math3.util.MathArrays#562;0.0',
#   'org.apache.commons.math3.util.MathArrays#563;0.0',
#   'org.apache.commons.math3.util.MathArrays#564;0.0',
#   'org.apache.commons.math3.util.MathArrays#565;0.0',
#   'org.apache.commons.math3.util.MathArrays#566;0.0',
#   'org.apache.commons.math3.util.MathArrays#567;0.0',
#   'org.apache.commons.math3.util.MathArrays#568;0.0',
#   'org.apache.commons.math3.util.MathArrays#569;0.0',
#   'org.apache.commons.math3.util.MathArrays#570;0.0',
#   'org.apache.commons.math3.util.MathArrays#571;0.0',
#   'org.apache.commons.math3.util.MathArrays#572;0.0',
#   'org.apache.commons.math3.util.MathArrays#573;0.0',
#   'org.apache.commons.math3.util.MathArrays#575;0.0',
#   'org.apache.commons.math3.util.MathArrays#576;0.0',
#   'org.apache.commons.math3.util.MathArrays#577;0.0',
#   'org.apache.commons.math3.util.MathArrays#578;0.0',
#   'org.apache.commons.math3.util.MathArrays#579;0.0',
#   'org.apache.commons.math3.util.MathArrays#580;0.0',
#   'org.apache.commons.math3.util.MathArrays#581;0.0',
#   'org.apache.commons.math3.util.MathArrays#582;0.0',
#   'org.apache.commons.math3.util.MathArrays#583;0.0',
#   'org.apache.commons.math3.util.MathArrays#587;0.0',
#   'org.apache.commons.math3.util.MathArrays#591;0.0',
#   'org.apache.commons.math3.util.MathArrays#592;0.0',
#   'org.apache.commons.math3.util.MathArrays#594;0.0',
#   'org.apache.commons.math3.util.MathArrays#595;0.0',
#   'org.apache.commons.math3.util.MathArrays#597;0.0',
#   'org.apache.commons.math3.util.MathArrays#598;0.0',
#   'org.apache.commons.math3.util.MathArrays#600;0.0',
#   'org.apache.commons.math3.util.MathArrays#604;0.0',
#   'org.apache.commons.math3.util.MathArrays#625;0.0',
#   'org.apache.commons.math3.util.MathArrays#626;0.0',
#   'org.apache.commons.math3.util.MathArrays#649;0.0',
#   'org.apache.commons.math3.util.MathArrays#650;0.0',
#   'org.apache.commons.math3.util.MathArrays#653;0.0',
#   'org.apache.commons.math3.util.MathArrays#654;0.0',
#   'org.apache.commons.math3.util.MathArrays#657;0.0',
#   'org.apache.commons.math3.util.MathArrays#658;0.0',
#   'org.apache.commons.math3.util.MathArrays#659;0.0',
#   'org.apache.commons.math3.util.MathArrays#660;0.0',
#   'org.apache.commons.math3.util.MathArrays#661;0.0',
#   'org.apache.commons.math3.util.MathArrays#662;0.0',
#   'org.apache.commons.math3.util.MathArrays#663;0.0',
#   'org.apache.commons.math3.util.MathArrays#665;0.0',
#   'org.apache.commons.math3.util.MathArrays#666;0.0',
#   'org.apache.commons.math3.util.MathArrays#668;0.0',
#   'org.apache.commons.math3.util.MathArrays#670;0.0',
#   'org.apache.commons.math3.util.MathArrays#673;0.0',
#   'org.apache.commons.math3.util.MathArrays#693;0.0',
#   'org.apache.commons.math3.util.MathArrays#695;0.0',
#   'org.apache.commons.math3.util.MathArrays#696;0.0',
#   'org.apache.commons.math3.util.MathArrays#697;0.0',
#   'org.apache.commons.math3.util.MathArrays#698;0.0',
#   'org.apache.commons.math3.util.MathArrays#699;0.0',
#   'org.apache.commons.math3.util.MathArrays#700;0.0',
#   'org.apache.commons.math3.util.MathArrays#703;0.0',
#   'org.apache.commons.math3.util.MathArrays#712;0.0',
#   'org.apache.commons.math3.util.MathArrays#722;0.0',
#   'org.apache.commons.math3.util.MathArrays#735;0.0',
#   'org.apache.commons.math3.util.MathArrays#736;0.0',
#   'org.apache.commons.math3.util.MathArrays#737;0.0',
#   'org.apache.commons.math3.util.MathArrays#750;0.0',
#   'org.apache.commons.math3.util.MathArrays#751;0.0',
#   'org.apache.commons.math3.util.MathArrays#752;0.0',
#   'org.apache.commons.math3.util.MathArrays#774;0.0',
#   'org.apache.commons.math3.util.MathArrays#775;0.0',
#   'org.apache.commons.math3.util.MathArrays#776;0.0',
#   'org.apache.commons.math3.util.MathArrays#779;0.0',
#   'org.apache.commons.math3.util.MathArrays#780;0.0',
#   'org.apache.commons.math3.util.MathArrays#782;0.0',
#   'org.apache.commons.math3.util.MathArrays#783;0.0',
#   'org.apache.commons.math3.util.MathArrays#784;0.0',
#   'org.apache.commons.math3.util.MathArrays#785;0.0',
#   'org.apache.commons.math3.util.MathArrays#786;0.0',
#   'org.apache.commons.math3.util.MathArrays#788;0.0',
#   'org.apache.commons.math3.util.MathArrays#789;0.0',
#   'org.apache.commons.math3.util.MathArrays#790;0.0',
#   'org.apache.commons.math3.util.MathArrays#791;0.0',
#   'org.apache.commons.math3.util.MathArrays#792;0.0',
#   'org.apache.commons.math3.util.MathArrays#793;0.0',
#   'org.apache.commons.math3.util.MathArrays#797;0.0',
#   'org.apache.commons.math3.util.MathArrays#801;0.0',
#   'org.apache.commons.math3.util.MathArrays#802;0.0',
#   'org.apache.commons.math3.util.MathArrays#803;0.0',
#   'org.apache.commons.math3.util.MathArrays#804;0.0',
#   'org.apache.commons.math3.util.MathArrays#805;0.0',
#   'org.apache.commons.math3.util.MathArrays#807;0.0',
#   'org.apache.commons.math3.util.MathArrays#808;0.0',
#   'org.apache.commons.math3.util.MathArrays#809;0.0',
#   'org.apache.commons.math3.util.MathArrays#810;0.0',
#   'org.apache.commons.math3.util.MathArrays#811;0.0',
#   'org.apache.commons.math3.util.MathArrays#812;0.0',
#   'org.apache.commons.math3.util.MathArrays#813;0.0',
#   'org.apache.commons.math3.util.MathArrays#816;0.0',
#   'org.apache.commons.math3.util.MathArrays#818;0.0',
#   'org.apache.commons.math3.util.MathArrays#821;0.0',
#   'org.apache.commons.math3.util.MathArrays#822;0.0',
#   'org.apache.commons.math3.util.MathArrays#823;0.0',
#   'org.apache.commons.math3.util.MathArrays#827;0.0',
#   'org.apache.commons.math3.util.MathArrays#866;0.0',
#   'org.apache.commons.math3.util.MathArrays#867;0.0',
#   'org.apache.commons.math3.util.MathArrays#868;0.0',
#   'org.apache.commons.math3.util.MathArrays#869;0.0',
#   'org.apache.commons.math3.util.MathArrays#870;0.0',
#   'org.apache.commons.math3.util.MathArrays#871;0.0',
#   'org.apache.commons.math3.util.MathArrays#874;0.0',
#   'org.apache.commons.math3.util.MathArrays#875;0.0',
#   'org.apache.commons.math3.util.MathArrays#878;0.0',
#   'org.apache.commons.math3.util.MathArrays#879;0.0',
#   'org.apache.commons.math3.util.MathArrays#880;0.0',
#   'org.apache.commons.math3.util.MathArrays#881;0.0',
#   'org.apache.commons.math3.util.MathArrays#882;0.0',
#   'org.apache.commons.math3.util.MathArrays#883;0.0',
#   'org.apache.commons.math3.util.MathArrays#886;0.0',
#   'org.apache.commons.math3.util.MathArrays#887;0.0',
#   'org.apache.commons.math3.util.MathArrays#890;0.0',
#   'org.apache.commons.math3.util.MathArrays#891;0.0',
#   'org.apache.commons.math3.util.MathArrays#892;0.0',
#   'org.apache.commons.math3.util.MathArrays#896;0.0',
#   'org.apache.commons.math3.util.MathArrays#898;0.0',
#   'org.apache.commons.math3.util.MathArrays#901;0.0',
#   'org.apache.commons.math3.util.MathArrays#904;0.0',
#   'org.apache.commons.math3.util.MathArrays#946;0.0',
#   'org.apache.commons.math3.util.MathArrays#947;0.0',
#   'org.apache.commons.math3.util.MathArrays#948;0.0',
#   'org.apache.commons.math3.util.MathArrays#949;0.0',
#   'org.apache.commons.math3.util.MathArrays#950;0.0',
#   'org.apache.commons.math3.util.MathArrays#951;0.0',
#   'org.apache.commons.math3.util.MathArrays#954;0.0',
#   'org.apache.commons.math3.util.MathArrays#955;0.0',
#   'org.apache.commons.math3.util.MathArrays#958;0.0',
#   'org.apache.commons.math3.util.MathArrays#959;0.0',
#   'org.apache.commons.math3.util.MathArrays#960;0.0',
#   'org.apache.commons.math3.util.MathArrays#961;0.0',
#   'org.apache.commons.math3.util.MathArrays#962;0.0',
#   'org.apache.commons.math3.util.MathArrays#963;0.0',
#   'org.apache.commons.math3.util.MathArrays#966;0.0',
#   'org.apache.commons.math3.util.MathArrays#967;0.0',
#   'org.apache.commons.math3.util.MathArrays#970;0.0',
#   'org.apache.commons.math3.util.MathArrays#971;0.0',
#   'org.apache.commons.math3.util.MathArrays#972;0.0',
#   'org.apache.commons.math3.util.MathArrays#973;0.0',
#   'org.apache.commons.math3.util.MathArrays#974;0.0',
#   'org.apache.commons.math3.util.MathArrays#975;0.0',
#   'org.apache.commons.math3.util.MathArrays#978;0.0',
#   'org.apache.commons.math3.util.MathArrays#979;0.0',
#   'org.apache.commons.math3.util.MathArrays#982;0.0',
#   'org.apache.commons.math3.util.MathArrays#983;0.0',
#   'org.apache.commons.math3.util.MathArrays#984;0.0',
#   'org.apache.commons.math3.util.MathArrays#987;0.0',
#   'org.apache.commons.math3.util.MathArrays#988;0.0',
#   'org.apache.commons.math3.util.MathArrays#989;0.0',
#   'org.apache.commons.math3.util.MathArrays#993;0.0',
#   'org.apache.commons.math3.util.MathArrays#995;0.0',
#   'org.apache.commons.math3.util.MathArrays#998;0.0',
#   'org.apache.commons.math3.util.MathArrays#1001;0.0',
#   'org.apache.commons.math3.util.MathArrays#1048;0.0',
#   'org.apache.commons.math3.util.MathArrays#1049;0.0',
#   'org.apache.commons.math3.util.MathArrays#1050;0.0',
#   'org.apache.commons.math3.util.MathArrays#1051;0.0',
#   'org.apache.commons.math3.util.MathArrays#1052;0.0',
#   'org.apache.commons.math3.util.MathArrays#1053;0.0',
#   'org.apache.commons.math3.util.MathArrays#1056;0.0',
#   'org.apache.commons.math3.util.MathArrays#1057;0.0',
#   'org.apache.commons.math3.util.MathArrays#1060;0.0',
#   'org.apache.commons.math3.util.MathArrays#1061;0.0',
#   'org.apache.commons.math3.util.MathArrays#1062;0.0',
#   'org.apache.commons.math3.util.MathArrays#1063;0.0',
#   'org.apache.commons.math3.util.MathArrays#1064;0.0',
#   'org.apache.commons.math3.util.MathArrays#1065;0.0',
#   'org.apache.commons.math3.util.MathArrays#1068;0.0',
#   'org.apache.commons.math3.util.MathArrays#1069;0.0',
#   'org.apache.commons.math3.util.MathArrays#1072;0.0',
#   'org.apache.commons.math3.util.MathArrays#1073;0.0',
#   'org.apache.commons.math3.util.MathArrays#1074;0.0',
#   'org.apache.commons.math3.util.MathArrays#1075;0.0',
#   'org.apache.commons.math3.util.MathArrays#1076;0.0',
#   'org.apache.commons.math3.util.MathArrays#1077;0.0',
#   'org.apache.commons.math3.util.MathArrays#1080;0.0',
#   'org.apache.commons.math3.util.MathArrays#1081;0.0',
#   'org.apache.commons.math3.util.MathArrays#1084;0.0',
#   'org.apache.commons.math3.util.MathArrays#1085;0.0',
#   'org.apache.commons.math3.util.MathArrays#1086;0.0',
#   'org.apache.commons.math3.util.MathArrays#1087;0.0',
#   'org.apache.commons.math3.util.MathArrays#1088;0.0',
#   'org.apache.commons.math3.util.MathArrays#1089;0.0',
#   'org.apache.commons.math3.util.MathArrays#1092;0.0',
#   'org.apache.commons.math3.util.MathArrays#1093;0.0',
#   'org.apache.commons.math3.util.MathArrays#1096;0.0',
#   'org.apache.commons.math3.util.MathArrays#1097;0.0',
#   'org.apache.commons.math3.util.MathArrays#1098;0.0',
#   'org.apache.commons.math3.util.MathArrays#1101;0.0',
#   'org.apache.commons.math3.util.MathArrays#1102;0.0',
#   'org.apache.commons.math3.util.MathArrays#1103;0.0',
#   'org.apache.commons.math3.util.MathArrays#1106;0.0',
#   'org.apache.commons.math3.util.MathArrays#1107;0.0',
#   'org.apache.commons.math3.util.MathArrays#1108;0.0',
#   'org.apache.commons.math3.util.MathArrays#1112;0.0',
#   'org.apache.commons.math3.util.MathArrays#1114;0.0',
#   'org.apache.commons.math3.util.MathArrays#1117;0.0',
#   'org.apache.commons.math3.util.MathArrays#1120;0.0',
#   'org.apache.commons.math3.util.MathArrays#1134;0.0',
#   'org.apache.commons.math3.util.MathArrays#1135;0.0',
#   'org.apache.commons.math3.util.MathArrays#1137;0.0',
#   'org.apache.commons.math3.util.MathArrays#1138;0.0',
#   'org.apache.commons.math3.util.MathArrays#1140;0.0',
#   'org.apache.commons.math3.util.MathArrays#1141;0.0',
#   'org.apache.commons.math3.util.MathArrays#1142;0.0',
#   'org.apache.commons.math3.util.MathArrays#1145;0.0',
#   'org.apache.commons.math3.util.MathArrays#1160;0.0',
#   'org.apache.commons.math3.util.MathArrays#1161;0.0',
#   'org.apache.commons.math3.util.MathArrays#1163;0.0',
#   'org.apache.commons.math3.util.MathArrays#1164;0.0',
#   'org.apache.commons.math3.util.MathArrays#1166;0.0',
#   'org.apache.commons.math3.util.MathArrays#1167;0.0',
#   'org.apache.commons.math3.util.MathArrays#1168;0.0',
#   'org.apache.commons.math3.util.MathArrays#1171;0.0',
#   'org.apache.commons.math3.util.MathArrays#1185;0.0',
#   'org.apache.commons.math3.util.MathArrays#1186;0.0',
#   'org.apache.commons.math3.util.MathArrays#1188;0.0',
#   'org.apache.commons.math3.util.MathArrays#1189;0.0',
#   'org.apache.commons.math3.util.MathArrays#1191;0.0',
#   'org.apache.commons.math3.util.MathArrays#1192;0.0',
#   'org.apache.commons.math3.util.MathArrays#1193;0.0',
#   'org.apache.commons.math3.util.MathArrays#1196;0.0',
#   'org.apache.commons.math3.util.MathArrays#1211;0.0',
#   'org.apache.commons.math3.util.MathArrays#1212;0.0',
#   'org.apache.commons.math3.util.MathArrays#1214;0.0',
#   'org.apache.commons.math3.util.MathArrays#1215;0.0',
#   'org.apache.commons.math3.util.MathArrays#1217;0.0',
#   'org.apache.commons.math3.util.MathArrays#1218;0.0',
#   'org.apache.commons.math3.util.MathArrays#1219;0.0',
#   'org.apache.commons.math3.util.MathArrays#1222;0.0',
#   'org.apache.commons.math3.util.MathArrays#1249;0.0',
#   'org.apache.commons.math3.util.MathArrays#1250;0.0',
#   'org.apache.commons.math3.util.MathArrays#1252;0.0',
#   'org.apache.commons.math3.util.MathArrays#1253;0.0',
#   'org.apache.commons.math3.util.MathArrays#1255;0.0',
#   'org.apache.commons.math3.util.MathArrays#1256;0.0',
#   'org.apache.commons.math3.util.MathArrays#1257;0.0',
#   'org.apache.commons.math3.util.MathArrays#1258;0.0',
#   'org.apache.commons.math3.util.MathArrays#1259;0.0',
#   'org.apache.commons.math3.util.MathArrays#1260;0.0024893363562981385',
#   'org.apache.commons.math3.util.MathArrays#1262;0.0',
#   'org.apache.commons.math3.util.MathArrays#1263;0.0',
#   'org.apache.commons.math3.util.MathArrays#1266;0.0',
#   'org.apache.commons.math3.util.MathArrays#1267;0.0',
#   'org.apache.commons.math3.util.MathArrays#1269;0.0',
#   'org.apache.commons.math3.util.MathArrays#1270;0.0',
#   'org.apache.commons.math3.util.MathArrays#1271;0.0',
#   'org.apache.commons.math3.util.MathArrays#1273;0.0',
#   'org.apache.commons.math3.util.MathArrays#1276;0.0',
#   'org.apache.commons.math3.util.MathArrays#1290;0.0',
#   'org.apache.commons.math3.util.MathArrays#1291;0.0',
#   'org.apache.commons.math3.util.MathArrays#1292;0.0',
#   'org.apache.commons.math3.util.MathArrays#1309;0.0',
#   'org.apache.commons.math3.util.MathArrays#1310;0.0',
#   'org.apache.commons.math3.util.MathArrays#1311;0.0',
#   'org.apache.commons.math3.util.MathArrays#1312;0.0',
#   'org.apache.commons.math3.util.MathArrays#1313;0.0',
#   'org.apache.commons.math3.util.MathArrays#1317;0.0',
#   'org.apache.commons.math3.util.MathArrays#1318;0.0',
#   'org.apache.commons.math3.util.MathArrays#1321;0.0',
#   'org.apache.commons.math3.exception.MathInternalError#37;0.0',
#   'org.apache.commons.math3.exception.MathInternalError#38;0.0',
#   'org.apache.commons.math3.exception.MathInternalError#39;0.0',
#   'org.apache.commons.math3.exception.MathInternalError#46;0.0',
#   'org.apache.commons.math3.exception.MathInternalError#47;0.0',
#   'org.apache.commons.math3.exception.MathInternalError#56;0.0',
#   'org.apache.commons.math3.exception.MathInternalError#57;0.0',
#   'org.apache.commons.math3.exception.MathIllegalStateException#45;0.0',
#   'org.apache.commons.math3.exception.MathIllegalStateException#46;0.0',
#   'org.apache.commons.math3.exception.MathIllegalStateException#47;0.0',
#   'org.apache.commons.math3.exception.MathIllegalStateException#48;0.0',
#   'org.apache.commons.math3.exception.MathIllegalStateException#60;0.0',
#   'org.apache.commons.math3.exception.MathIllegalStateException#61;0.0',
#   'org.apache.commons.math3.exception.MathIllegalStateException#62;0.0',
#   'org.apache.commons.math3.exception.MathIllegalStateException#63;0.0',
#   'org.apache.commons.math3.exception.MathIllegalStateException#69;0.0',
#   'org.apache.commons.math3.exception.MathIllegalStateException#70;0.0',
#   'org.apache.commons.math3.exception.MathIllegalStateException#74;0.0',
#   'org.apache.commons.math3.exception.MathIllegalStateException#80;0.0',
#   'org.apache.commons.math3.exception.MathIllegalStateException#86;0.0',
#   'org.apache.commons.math3.util.Pair#45;0.0',
#   'org.apache.commons.math3.util.Pair#46;0.0',
#   'org.apache.commons.math3.util.Pair#47;0.0',
#   'org.apache.commons.math3.util.Pair#48;0.0',
#   'org.apache.commons.math3.util.Pair#56;0.0',
#   'org.apache.commons.math3.util.Pair#57;0.0',
#   'org.apache.commons.math3.util.Pair#65;0.0',
#   'org.apache.commons.math3.util.Pair#74;0.0',
#   'org.apache.commons.math3.util.Pair#84;0.0',
#   'org.apache.commons.math3.util.Pair#94;0.0',
#   'org.apache.commons.math3.util.Pair#106;0.0',
#   'org.apache.commons.math3.util.Pair#107;0.0',
#   'org.apache.commons.math3.util.Pair#109;0.0',
#   'org.apache.commons.math3.util.Pair#110;0.0',
#   'org.apache.commons.math3.util.Pair#112;0.0',
#   'org.apache.commons.math3.util.Pair#113;0.0',
#   'org.apache.commons.math3.util.Pair#129;0.0',
#   'org.apache.commons.math3.util.Pair#131;0.0',
#   'org.apache.commons.math3.util.Pair#132;0.0',
#   'org.apache.commons.math3.util.Pair#134;0.0',
#   'org.apache.commons.math3.exception.DimensionMismatchException#44;0.0',
#   'org.apache.commons.math3.exception.DimensionMismatchException#45;0.0',
#   'org.apache.commons.math3.exception.DimensionMismatchException#46;0.0',
#   'org.apache.commons.math3.exception.DimensionMismatchException#56;0.0',
#   'org.apache.commons.math3.exception.DimensionMismatchException#57;0.0',
#   'org.apache.commons.math3.exception.DimensionMismatchException#63;0.0',
#   'org.apache.commons.math3.exception.MathIllegalNumberException#46;0.0',
#   'org.apache.commons.math3.exception.MathIllegalNumberException#47;0.0',
#   'org.apache.commons.math3.exception.MathIllegalNumberException#48;0.0024923396148435195',
#   'org.apache.commons.math3.exception.MathIllegalNumberException#54;0.0',
#   'org.apache.commons.math3.exception.MathIllegalArgumentException#44;0.004031411282360842',
#   'org.apache.commons.math3.exception.MathIllegalArgumentException#45;0.0',
#   'org.apache.commons.math3.exception.MathIllegalArgumentException#46;0.0',
#   'org.apache.commons.math3.exception.MathIllegalArgumentException#47;0.000622503674821584',
#   'org.apache.commons.math3.exception.MathIllegalArgumentException#51;0.0',
#   'org.apache.commons.math3.exception.MathIllegalArgumentException#57;0.0',
#   'org.apache.commons.math3.exception.MathIllegalArgumentException#63;0.0',
#   'org.apache.commons.math3.exception.MathArithmeticException#43;0.0',
#   'org.apache.commons.math3.exception.MathArithmeticException#44;0.0',
#   'org.apache.commons.math3.exception.MathArithmeticException#45;0.0',
#   'org.apache.commons.math3.exception.MathArithmeticException#46;0.0',
#   'org.apache.commons.math3.exception.MathArithmeticException#56;0.0',
#   'org.apache.commons.math3.exception.MathArithmeticException#57;0.0',
#   'org.apache.commons.math3.exception.MathArithmeticException#58;0.0',
#   'org.apache.commons.math3.exception.MathArithmeticException#59;0.0',
#   'org.apache.commons.math3.exception.MathArithmeticException#63;0.0',
#   'org.apache.commons.math3.exception.MathArithmeticException#69;0.0',
#   'org.apache.commons.math3.exception.MathArithmeticException#75;0.0',
#   'org.apache.commons.math3.exception.NotPositiveException#37;0.0',
#   'org.apache.commons.math3.exception.NotPositiveException#38;0.0',
#   'org.apache.commons.math3.exception.NotPositiveException#47;0.0',
#   'org.apache.commons.math3.exception.NotPositiveException#48;0.0',
#   'org.apache.commons.math3.exception.NumberIsTooSmallException#50;0.0',
#   'org.apache.commons.math3.exception.NumberIsTooSmallException#54;0.0',
#   'org.apache.commons.math3.exception.NumberIsTooSmallException#68;0.0',
#   'org.apache.commons.math3.exception.NumberIsTooSmallException#70;0.0024076299015103886',
#   'org.apache.commons.math3.exception.NumberIsTooSmallException#71;0.0',
#   'org.apache.commons.math3.exception.NumberIsTooSmallException#72;0.0',
#   'org.apache.commons.math3.exception.NumberIsTooSmallException#78;0.0',
#   'org.apache.commons.math3.exception.NumberIsTooSmallException#85;0.0',
#   'org.apache.commons.math3.exception.NotStrictlyPositiveException#38;0.0',
#   'org.apache.commons.math3.exception.NotStrictlyPositiveException#39;0.0',
#   'org.apache.commons.math3.exception.NotStrictlyPositiveException#48;0.0',
#   'org.apache.commons.math3.exception.NotStrictlyPositiveException#49;0.0',
#   'org.apache.commons.math3.exception.NonMonotonicSequenceException#61;0.0',
#   'org.apache.commons.math3.exception.NonMonotonicSequenceException#62;0.0',
#   'org.apache.commons.math3.exception.NonMonotonicSequenceException#80;0.0',
#   'org.apache.commons.math3.exception.NonMonotonicSequenceException#89;0.0',
#   'org.apache.commons.math3.exception.NonMonotonicSequenceException#90;0.0',
#   'org.apache.commons.math3.exception.NonMonotonicSequenceException#91;0.0',
#   'org.apache.commons.math3.exception.NonMonotonicSequenceException#92;0.0',
#   'org.apache.commons.math3.exception.NonMonotonicSequenceException#93;0.0',
#   'org.apache.commons.math3.exception.NonMonotonicSequenceException#99;0.0',
#   'org.apache.commons.math3.exception.NonMonotonicSequenceException#105;0.0',
#   'org.apache.commons.math3.exception.NonMonotonicSequenceException#113;0.0',
#   'org.apache.commons.math3.exception.NonMonotonicSequenceException#119;0.0',
#   'org.apache.commons.math3.exception.NullArgumentException#41;0.0',
#   'org.apache.commons.math3.exception.NullArgumentException#42;0.0',
#   'org.apache.commons.math3.exception.NullArgumentException#50;0.0',
#   'org.apache.commons.math3.exception.NullArgumentException#51;0.0',
#   'org.apache.commons.math3.util.MathArrays$OrderDirection#260;0.0',
#   'org.apache.commons.math3.util.MathArrays$OrderDirection#262;0.0',
#   'org.apache.commons.math3.util.MathArrays$OrderDirection#264;0.0',
#   'org.apache.commons.math3.util.MathArrays$2#283;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#69;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#70;0.0007113158760402583',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#86;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#87;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#89;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#90;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#92;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#93;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#94;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#95;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#96;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#98;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#101;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#102;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#110;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#111;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#123;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#125;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#126;0.00083818543683567',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#128;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#132;0.00166571100999241',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#142;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#144;0.012636994547126051',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#145;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#148;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#157;0.004141814885653294',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#158;0.004673149123681969',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#160;0.0012955653887005425',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#161;0.006801978101329431',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#162;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#163;0.003952763018591904',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#170;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#182;0.007351435600092993',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#183;0.0',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#187;0.015687902830843786',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#189;0.005075858670377312',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#190;0.007701223428150272',
#   'org.apache.commons.math3.distribution.DiscreteDistribution#193;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#66;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#67;0.01217976658329134',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#87;0.0012969576387044657',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#88;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#89;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#92;0.0034801563996210982',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#94;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#95;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#98;0.011613852151774795',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#99;0.0027104800441871135',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#106;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#119;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#126;0.0022107821246702547',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#128;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#129;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#130;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#132;0.005775850450016107',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#134;0.005448620518472863',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#143;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#145;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#146;0.007408400956254224',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#147;0.0021417901060733213',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#149;0.0014020282243071558',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#158;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#159;0.0020705607714598395',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#161;0.0034208043549971423',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#162;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#163;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#164;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#166;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#177;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#178;0.00436306131088858',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#179;0.0007480853488358308',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#180;0.008168376280648065',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#182;0.008001804542140473',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#184;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#195;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#196;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#197;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#198;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#200;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#202;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#213;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#224;0.004261257784414815',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#235;0.0',
#   'org.apache.commons.math3.distribution.DiscreteRealDistribution#243;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#67;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#50;0.00016989019643817715',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#60;0.01676087399426568',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#70;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#71;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#76;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#77;0.004145371831680289',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#78;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#91;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#112;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#113;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#116;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#157;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#158;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#161;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#162;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#163;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#166;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#167;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#168;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#171;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#172;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#174;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#177;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#178;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#179;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#181;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#182;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#183;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#188;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#189;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#190;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#192;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#193;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#194;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#199;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#206;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#211;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#213;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#214;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#215;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#216;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#217;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#218;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#219;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#220;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#221;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#223;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#225;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#226;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#230;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#241;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#246;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#247;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#248;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#259;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#269;0.0023474162403300247',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#270;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#273;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#274;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#275;0.002821427502525453',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#277;0.004491834119314891',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution#287;0.0',
#   'org.apache.commons.math3.exception.NumberIsTooLargeException#50;0.0',
#   'org.apache.commons.math3.exception.NumberIsTooLargeException#54;0.0',
#   'org.apache.commons.math3.exception.NumberIsTooLargeException#67;0.0',
#   'org.apache.commons.math3.exception.NumberIsTooLargeException#69;0.0',
#   'org.apache.commons.math3.exception.NumberIsTooLargeException#70;0.0',
#   'org.apache.commons.math3.exception.NumberIsTooLargeException#71;0.0',
#   'org.apache.commons.math3.exception.NumberIsTooLargeException#77;0.0',
#   'org.apache.commons.math3.exception.NumberIsTooLargeException#84;0.0',
#   'org.apache.commons.math3.exception.OutOfRangeException#46;0.0',
#   'org.apache.commons.math3.exception.OutOfRangeException#47;0.0',
#   'org.apache.commons.math3.exception.OutOfRangeException#62;0.0',
#   'org.apache.commons.math3.exception.OutOfRangeException#63;0.0',
#   'org.apache.commons.math3.exception.OutOfRangeException#64;0.0',
#   'org.apache.commons.math3.exception.OutOfRangeException#65;0.0',
#   'org.apache.commons.math3.exception.OutOfRangeException#71;0.0',
#   'org.apache.commons.math3.exception.OutOfRangeException#77;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution$1#199;0.0',
#   'org.apache.commons.math3.distribution.AbstractRealDistribution$1#202;0.0',
#   'org.apache.commons.math3.random.Well19937c#57;0.0',
#   'org.apache.commons.math3.random.Well19937c#58;0.0',
#   'org.apache.commons.math3.random.Well19937c#64;0.0',
#   'org.apache.commons.math3.random.Well19937c#65;0.0',
#   'org.apache.commons.math3.random.Well19937c#72;0.0',
#   'org.apache.commons.math3.random.Well19937c#73;0.0',
#   'org.apache.commons.math3.random.Well19937c#79;0.004671423485164999',
#   'org.apache.commons.math3.random.Well19937c#80;0.0',
#   'org.apache.commons.math3.random.Well19937c#86;0.0',
#   'org.apache.commons.math3.random.Well19937c#87;0.00839634531325073',
#   'org.apache.commons.math3.random.Well19937c#89;0.0',
#   'org.apache.commons.math3.random.Well19937c#90;0.0029871560648079276',
#   'org.apache.commons.math3.random.Well19937c#91;0.005594473571721104',
#   'org.apache.commons.math3.random.Well19937c#92;0.00843220633389763',
#   'org.apache.commons.math3.random.Well19937c#94;0.0024601144450032697',
#   'org.apache.commons.math3.random.Well19937c#95;0.0',
#   'org.apache.commons.math3.random.Well19937c#96;0.004753303829703126',
#   'org.apache.commons.math3.random.Well19937c#97;0.005004431297122192',
#   'org.apache.commons.math3.random.Well19937c#98;0.0',
#   'org.apache.commons.math3.random.Well19937c#100;0.004166704089908435',
#   'org.apache.commons.math3.random.Well19937c#101;0.0',
#   'org.apache.commons.math3.random.Well19937c#102;0.0037378214459561077',
#   'org.apache.commons.math3.random.Well19937c#103;0.008036922883254971',
#   'org.apache.commons.math3.random.Well19937c#108;0.001604468698950895',
#   'org.apache.commons.math3.random.Well19937c#109;0.0',
#   'org.apache.commons.math3.random.Well19937c#111;0.011713886549072156',
#   'org.apache.commons.math3.random.AbstractWell#72;0.0',
#   'org.apache.commons.math3.random.AbstractWell#73;0.0',
#   'org.apache.commons.math3.random.AbstractWell#83;0.0',
#   'org.apache.commons.math3.random.AbstractWell#84;0.0',
#   'org.apache.commons.math3.random.AbstractWell#94;0.0',
#   'org.apache.commons.math3.random.AbstractWell#99;0.0',
#   'org.apache.commons.math3.random.AbstractWell#100;0.0',
#   'org.apache.commons.math3.random.AbstractWell#101;0.0',
#   'org.apache.commons.math3.random.AbstractWell#102;0.0',
#   'org.apache.commons.math3.random.AbstractWell#106;0.0',
#   'org.apache.commons.math3.random.AbstractWell#107;0.0',
#   'org.apache.commons.math3.random.AbstractWell#108;0.0',
#   'org.apache.commons.math3.random.AbstractWell#109;0.0',
#   'org.apache.commons.math3.random.AbstractWell#110;0.0',
#   'org.apache.commons.math3.random.AbstractWell#111;0.0',
#   'org.apache.commons.math3.random.AbstractWell#112;0.0',
#   'org.apache.commons.math3.random.AbstractWell#113;0.0',
#   'org.apache.commons.math3.random.AbstractWell#114;0.0',
#   'org.apache.commons.math3.random.AbstractWell#115;0.0',
#   'org.apache.commons.math3.random.AbstractWell#116;0.0',
#   'org.apache.commons.math3.random.AbstractWell#120;0.0',
#   'org.apache.commons.math3.random.AbstractWell#122;0.0',
#   'org.apache.commons.math3.random.AbstractWell#132;0.0',
#   'org.apache.commons.math3.random.AbstractWell#133;0.01272689987418077',
#   'org.apache.commons.math3.random.AbstractWell#142;0.0',
#   'org.apache.commons.math3.random.AbstractWell#143;0.0',
#   'org.apache.commons.math3.random.AbstractWell#154;0.0',
#   'org.apache.commons.math3.random.AbstractWell#155;0.0',
#   'org.apache.commons.math3.random.AbstractWell#156;0.0',
#   'org.apache.commons.math3.random.AbstractWell#159;0.0',
#   'org.apache.commons.math3.random.AbstractWell#161;0.0',
#   'org.apache.commons.math3.random.AbstractWell#162;0.0',
#   'org.apache.commons.math3.random.AbstractWell#163;0.0',
#   'org.apache.commons.math3.random.AbstractWell#164;0.0',
#   'org.apache.commons.math3.random.AbstractWell#168;0.0',
#   'org.apache.commons.math3.random.AbstractWell#169;0.0',
#   'org.apache.commons.math3.random.AbstractWell#170;0.0',
#   'org.apache.commons.math3.random.AbstractWell#179;0.0',
#   'org.apache.commons.math3.random.AbstractWell#180;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#40;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#41;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#42;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#66;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#71;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#72;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#73;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#74;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#75;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#76;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#77;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#78;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#79;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#80;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#81;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#82;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#83;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#84;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#86;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#90;0.008341185211781482',
#   'org.apache.commons.math3.random.BitsStreamGenerator#91;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#92;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#97;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#104;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#106;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#107;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#108;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#109;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#110;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#111;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#112;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#114;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#115;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#118;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#124;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#143;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#144;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#145;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#150;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#151;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#152;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#153;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#155;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#160;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#161;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#162;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#170;0.0',
#   'org.apache.commons.math3.random.BitsStreamGenerator#171;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#131;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#118;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#121;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#132;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#141;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#142;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#143;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#162;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#163;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#167;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#170;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#173;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#174;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#177;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#178;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#185;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#188;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#189;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#191;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#193;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#198;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#199;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#202;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#203;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#204;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#209;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#210;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#213;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#214;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#215;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#236;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#237;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#241;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#242;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#244;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#248;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#245;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#247;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#249;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#252;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#254;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#255;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#256;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#257;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#258;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#261;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#264;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#265;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#272;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#275;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#276;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#278;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#281;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#286;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#287;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#290;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#291;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#292;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#293;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#298;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#299;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#302;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#303;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#304;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#305;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#323;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#330;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#331;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#333;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#348;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#375;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#392;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#407;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#418;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#432;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#446;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#457;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#469;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#480;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#491;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#505;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#524;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#545;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#546;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#550;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#551;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#553;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#554;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#557;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#558;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#561;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#564;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#565;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#566;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#569;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#585;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#586;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#589;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#590;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#594;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#595;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#596;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#597;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#598;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#601;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#619;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#620;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#621;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#624;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#625;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#628;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#629;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#630;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#631;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#632;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#634;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#648;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#649;0.0006273114983852968',
#   'org.apache.commons.math3.random.RandomDataGenerator#659;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#660;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#671;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#672;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#679;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#680;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#700;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#701;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#714;0.011664853194568503',
#   'org.apache.commons.math3.random.RandomDataGenerator#715;0.0033779281759553914',
#   'org.apache.commons.math3.random.RandomDataGenerator#717;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#725;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#726;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#738;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#739;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#740;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#742;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#753;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#754;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#755;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#756;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#759;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#761;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#762;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#763;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#765;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#774;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#775;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#776;0.0',
#   'org.apache.commons.math3.random.RandomDataGenerator#778;0.0',
#   'org.apache.commons.math3.exception.NotFiniteNumberException#40;0.0',
#   'org.apache.commons.math3.exception.NotFiniteNumberException#41;0.0',
#   'org.apache.commons.math3.exception.NotFiniteNumberException#53;0.0',
#   'org.apache.commons.math3.exception.NotFiniteNumberException#54;0.0',
#   'org.apache.commons.math3.exception.NotANumberException#35;0.0',
#   'org.apache.commons.math3.exception.NotANumberException#36;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#114;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#115;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#116;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#126;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#127;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#128;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#136;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#156;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#161;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#166;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#186;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#191;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#196;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#213;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#218;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#233;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#248;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#265;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#279;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#293;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#307;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#320;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#336;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#363;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#383;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#401;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#415;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#431;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#447;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#461;0.0007971069258637664',
#   'org.apache.commons.math3.random.RandomDataImpl#462;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#472;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#473;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#485;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#486;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#493;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#494;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#518;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#519;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#532;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#550;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#565;0.0',
#   'org.apache.commons.math3.random.RandomDataImpl#581;0.0']}

# %%
shap_lines_output_val = {}

for i in shap_to_txt:
    for index, value in enumerate(shap_to_txt[i]):
        feature_shapval = value.split(";")
        feature = feature_shapval[0]
        shapval = feature_shapval[1]
        if feature not in shap_lines_output_val:
            shap_lines_output_val[feature] = []
        shap_lines_output_val[feature].append(float(shapval))

# %%
shap_means = {}
shap_max = {}
shap_min = {}

for i in shap_lines_output_val:
    if i not in shap_means:
        shap_means[i] = []
    if i not in shap_min:
        shap_min[i] = shap_lines_output_val[i][0]
    if i not in shap_max:
        shap_max[i] = shap_lines_output_val[i][0]
    for j in shap_lines_output_val[i]:
        shap_means[i].append(j)
        if abs(shap_max[i]) < abs(j):
            shap_max[i] = j
        if abs(shap_min[i]) > abs(j):
            shap_min[i] = j

for i in shap_means:
    shap_means[i] = sum(shap_means[i]) / len(shap_means[i])

# %%
with open("Math-8_knn-shap_results.txt", "w") as file:
    for i in shap_to_txt:
        file.write(str(i) + "\n")
        for j in range(len(shap_to_txt[i])):
            file.write(shap_to_txt[i][j] + "\n")

# %%
write_output_file('Math-8_knn-shap_mean.txt', shap_means, is_reverse=True)
write_output_file('Math-8_knn-shap_min.txt', shap_min, is_reverse=True)
write_output_file('Math-8_knn-shap_max.txt', shap_max, is_reverse=True)
